# %%
import env 
import pandas as pd
import os

# %% [markdown]
# # First we need gather(acquire) the data.

# %%
# First we need to use our env file to access our mysql data base
def get_connection():
    
    '''
    This function will return the link to access mysql database. 
    '''
    user=env.username
    password=env.password
    host=env.host
    db=env.db
    return f'mysql+pymysql://{user}:{password}@{host}/{db}'

# %%
# build the query
# We are importing everything, below we are writing the query to query everything 

query =\
'''
select * 
from customers
left join internet_service_types using(internet_service_type_id)
left join contract_types using(contract_type_id)
left join payment_types using(payment_type_id)
left join customer_signups using (customer_id)
left join customer_churn using(customer_id)
left join customer_contracts using (customer_id)
left join customer_details using (customer_id)
left join customer_payments using (customer_id)
left join customer_subscriptions using (customer_id)
'''

# %%
def get_telco_data():
    if os.path.exists('telco.csv') == True:
        return pd.read_csv('telco.csv')
    else:
        df = pd.read_sql(query, get_connection())
        df.to_csv('telco.csv')
        return pd.read_csv('telco.csv')

# %% [markdown]
# # Test the function
# ***** MAKE SURE YOU DO NOT!!!! PUSH ENV FILE. CYBER SAFETY IS IMPORTANT!******

# %%
df = get_telco_data()
# Out:
#       Unnamed: 0 customer_id  payment_type_id  contract_type_id  \
# 0              0  0002-ORFBO                2                 2
# 1              1  0003-MKNFE                2                 1
# 2              2  0004-TLHLJ                1                 1
# 3              3  0011-IGKFF                1                 1
# 4              4  0013-EXCHZ                2                 1
# ...          ...         ...              ...               ...
# 7038        7038  9979-RGMZT                2                 2
# 7039        7039  9985-MWVIX                2                 1
# 7040        7040  9986-BONCE                3                 1
# 7041        7041  9992-UJOEL                2                 1
# 7042        7042  9995-HOTOH                1                 3
#
#       internet_service_type_id  gender  senior_citizen partner dependents  \
# 0                            1  Female               0     Yes        Yes
# 1                            1    Male               0      No         No
# 2                            2    Male               0      No         No
# 3                            2    Male               1     Yes         No
# 4                            2  Female               1     Yes         No
# ...                        ...     ...             ...     ...        ...
# 7038                         2  Female               0      No         No
# 7039                         2  Female               0      No         No
# 7040                         3  Female               0      No         No
# 7041                         1    Male               0      No         No
# 7042                         1    Male               0     Yes        Yes
#
#       tenure  ... total_charges.1 phone_service.1  multiple_lines.1  \
# 0          9  ...           593.3             Yes                No
# 1          9  ...           542.4             Yes               Yes
# 2          4  ...          280.85             Yes                No
# 3         13  ...         1237.85             Yes                No
# 4          3  ...           267.4             Yes                No
# ...      ...  ...             ...             ...               ...
# 7038       7  ...          633.45             Yes                No
# 7039       1  ...           70.15             Yes                No
# 7040       4  ...            85.5             Yes                No
# 7041       2  ...           92.75             Yes                No
# 7042      63  ...          3707.6              No  No phone service
#
#      internet_service_type_id.1    online_security.1      online_backup.1  \
# 0                             1                   No                  Yes
# 1                             1                   No                   No
# 2                             2                   No                   No
# 3                             2                   No                  Yes
# 4                             2                   No                   No
# ...                         ...                  ...                  ...
# 7038                          2                   No                  Yes
# 7039                          2                   No                   No
# 7040                          3  No internet service  No internet service
# 7041                          1                   No                  Yes
# 7042                          1                  Yes                  Yes
#
#       device_protection.1       tech_support.1       streaming_tv.1  \
# 0                      No                  Yes                  Yes
# 1                      No                   No                   No
# 2                     Yes                   No                   No
# 3                     Yes                   No                  Yes
# 4                      No                  Yes                  Yes
# ...                   ...                  ...                  ...
# 7038                   No                   No                  Yes
# 7039                   No                   No                   No
# 7040  No internet service  No internet service  No internet service
# 7041                   No                   No                   No
# 7042                  Yes                   No                  Yes
#
#        streaming_movies.1
# 0                      No
# 1                     Yes
# 2                      No
# 3                     Yes
# 4                      No
# ...                   ...
# 7038                  Yes
# 7039                   No
# 7040  No internet service
# 7041                   No
# 7042                  Yes
#
# [7043 rows x 45 columns]

# %%
df
